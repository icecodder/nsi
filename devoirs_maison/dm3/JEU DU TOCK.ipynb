# %% [markdown]
# # NSI | DM - Types Construits, Exercice 6: le jeu du TOC
# On cherche à simuler de nombreuses parties pour estimer la durée moyenne d'une partie.
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Tock_board_%28taken_without_flash%29.jpg/220px-Tock_board_%28taken_without_flash%29.jpg)
#
#  **1. Définir la liste des éléments à coder**
# - Les règles du jeu: nombres de joueurs, nombres de cases, cases par défaut et cases spéciales
# - Le paquet de 54 cartes
# - Les joueurs
# - Une fonction pour créer le plateau de jeu
# - Une fonction pour les déplacements des pions
# - Une fonction pour lancer une partie
# - Une fonction pour simuler plusieurs parties
# - Une fonction pour exporter les parties en .csv
# - Des listes pour créer le graphique avec matplotlib
#
#  **2. Définir la structure de donnée de chaque élément et du jeu (tuples, listes, dictionnaires, structures
# imbriquées).**
# - Les règles du jeu: dico de int et de tuple
# - Joueur: Int
# - Le paquet de 54 cartes: int via le module random
# - Les listes pour matplotlib: list
#
#  **3. Ecrire des fonctions et les tests pour répondre au problème**
#
# On importe les modules que l'on va utilisés:

# %%
from pprint import pprint # Pretty-Print pour afficher des listes plus jolies
from random import randint # Random pour choisir un nombre au hasard
import matplotlib.pyplot as plt # MatPlotLib pour les graphiques
import csv # CSV pour créer le tableau

# %%
regles = {
    "nb_joueurs": 4,
    "nb_cases": 18,
    "defaut": (0, "normal"),
    "cases_speciales": {
        17: (2, "maison"),
        18: (3, "départ")
    }
}

# %%
pprint(regles)
# Out:
# {'cases_speciales': {17: (2, 'maison'), 18: (3, 'départ')},
#  'defaut': (0, 'normal'),
#  'nb_cases': 18,
#  'nb_joueurs': 4}

# %% [markdown]
# On crée une fonction pour créer le plateau de jeu:
# PS: list avec le plateau de jeu

# %%
# Création du plateau de jeu
def creer_plateau():
    plateau = []

    for i in range(regles["nb_cases"]):
        case = i + 1

        # Ajout des cases spéciales
        if case in regles["cases_speciales"].keys():
            #print(case, regles["cases_speciales"][case])
            plateau.append(regles["cases_speciales"][case])
        # Ajout des cases normales
        else:
            #print(case, regles["defaut"])
            plateau.append(regles["defaut"])

    return plateau * regles["nb_joueurs"]

# %%
plateau = creer_plateau()
pprint(plateau)
# Out:
# [(0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (2, 'maison'),
#  (3, 'départ'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (2, 'maison'),
#  (3, 'départ'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (2, 'maison'),
#  (3, 'départ'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (0, 'normal'),
#  (2, 'maison'),
#  (3, 'départ')]

# %% [markdown]
# On crée les pions,
# pour une version simplifiée chaque joueur on seulement 1 pion

# %%
# Créations des pions
# Joueur X = (Pion, Position)
joueur_1 = -1
joueur_2 = -1
joueur_3 = -1
joueur_4 = -1

# %% [markdown]
# On crée une fonction pour faire déplacer le pion,
# PE: int, le joueur
# PS: - int, le joueur
#     - int, sa carte jouée

# %%
# Déplacement du pion
def deplacer_pion(joueur):
    carte = randint(1, 13)

    # Récupération du nombre de cases totales
    nb_cases_tot = regles["nb_cases"] * regles["nb_joueurs"]

    # Si le joueurr n'a pas un AS (1) ou un ROI (13), il ne peut pas rentrer dans le plateau de jeu
    if joueur == -1:
        if carte == 1 or carte == 13:
            joueur = 18
        else:
            joueur = -1
    else:
        # Si le joueur à un 4, il recule de 4 cases
        if carte == 4:
            joueur -= carte
        # Sinon le joueur avance du nombres de cases correspondant à la carte
        else:
            joueur += carte

    # Si le joueur est arrivé à la case départ, il revient au début
    if joueur > nb_cases_tot:
        joueur -= nb_cases_tot

    return joueur, carte

# %% [markdown]
# Test des déplacements

# %%
joueur_1, carte_1 = deplacer_pion(joueur_1)
joueur_2, carte_2 = deplacer_pion(joueur_2)
joueur_3, carte_3 = deplacer_pion(joueur_3)
joueur_4, carte_4 = deplacer_pion(joueur_4)
print(f"Le joueur 1 est sur la case {joueur_1} et a jouée {carte_1}")
# Out:
# Le joueur 1 est sur la case -1 et a jouée 2

# %% [markdown]
# On crée une fonction pour lancer une partie,
# PE: int, chaque joueur
# PS: - list, les informations de la partie
#     - int, le gagnant

# %%
# Fonction pour lancer une partie
def lancer_partie(joueur_1, joueur_2, joueur_3, joueur_4):
    etape = 1
    partie = []
    gagnant = 0
    
    # Tant qu'un des joueurs n'est pas arrivé à la maison, on continue
    while joueur_1 != 17 and joueur_2 != 17 and joueur_3 != 17 and joueur_4 != 17:
        # Déplacement du joueur 1
        joueur_1, carte_1 = deplacer_pion(joueur_1)
        # Vérification si le joueur 1 a gagné
        if joueur_1 == 17:
            gagnant = 1

        # Déplacement du joueur 2
        joueur_2, carte_2 = deplacer_pion(joueur_2)
        # Vérification si le joueur 2 a gagné
        if joueur_2 == 17:
            gagnant = 2

        # Déplacement du joueur 3
        joueur_3, carte_3 = deplacer_pion(joueur_3)
        # Vérification si le joueur 3 a gagné
        if joueur_3 == 17:
            gagnant = 3

        # Déplacement du joueur 4
        joueur_4, carte_4 = deplacer_pion(joueur_4)
        # Vérification si le joueur 4 a gagné
        if joueur_4 == 17:
            gagnant = 4

        # Ajout des informations à la partie
        partie.append({
            "Etape": etape,
            "Carte J1": carte_1,
            "Carte J2": carte_2,
            "Carte J3": carte_3,
            "Carte J4": carte_4,
        })

        etape += 1

    return partie, gagnant

# %% [markdown]
# Lancement d'une partie

# %%
partie, gagnant = lancer_partie(joueur_1, joueur_2, joueur_3, joueur_4)
pprint(partie)
print(f"Le gagant est Joueur {gagnant} en {len(partie)} étapes")
# Out:
# [{'Carte J1': 9, 'Carte J2': 2, 'Carte J3': 12, 'Carte J4': 11, 'Etape': 1},
#  {'Carte J1': 2, 'Carte J2': 2, 'Carte J3': 12, 'Carte J4': 6, 'Etape': 2},
#  {'Carte J1': 7, 'Carte J2': 5, 'Carte J3': 6, 'Carte J4': 13, 'Etape': 3},
#  {'Carte J1': 6, 'Carte J2': 7, 'Carte J3': 12, 'Carte J4': 6, 'Etape': 4},
#  {'Carte J1': 3, 'Carte J2': 1, 'Carte J3': 4, 'Carte J4': 3, 'Etape': 5},
#  {'Carte J1': 12, 'Carte J2': 2, 'Carte J3': 7, 'Carte J4': 12, 'Etape': 6},
#  {'Carte J1': 5, 'Carte J2': 4, 'Carte J3': 4, 'Carte J4': 2, 'Etape': 7},
#  {'Carte J1': 11, 'Carte J2': 12, 'Carte J3': 3, 'Carte J4': 11, 'Etape': 8},
#  {'Carte J1': 1, 'Carte J2': 4, 'Carte J3': 3, 'Carte J4': 7, 'Etape': 9},
#  {'Carte J1': 4, 'Carte J2': 7, 'Carte J3': 5, 'Carte J4': 3, 'Etape': 10},
#  {'Carte J1': 10, 'Carte J2': 5, 'Carte J3': 6, 'Carte J4': 6, 'Etape': 11},
#  {'Carte J1': 9, 'Carte J2': 5, 'Carte J3': 2, 'Carte J4': 4, 'Etape': 12},
#  {'Carte J1': 7, 'Carte J2': 1, 'Carte J3': 13, 'Carte J4': 11, 'Etape': 13},
#  {'Carte J1': 8, 'Carte J2': 7, 'Carte J3': 8, 'Carte J4': 4, 'Etape': 14},
#  {'Carte J1': 12, 'Carte J2': 8, 'Carte J3': 12, 'Carte J4': 1, 'Etape': 15},
#  {'Carte J1': 3, 'Carte J2': 11, 'Carte J3': 11, 'Carte J4': 6, 'Etape': 16},
#  {'Carte J1': 10, 'Carte J2': 8, 'Carte J3': 13, 'Carte J4': 1, 'Etape': 17},
#  {'Carte J1': 4, 'Carte J2': 13, 'Carte J3': 6, 'Carte J4': 13, 'Etape': 18},
#  {'Carte J1': 2, 'Carte J2': 4, 'Carte J3': 11, 'Carte J4': 3, 'Etape': 19},
#  {'Carte J1': 7, 'Carte J2': 7, 'Carte J3': 2, 'Carte J4': 3, 'Etape': 20},
#  {'Carte J1': 6, 'Carte J2': 9, 'Carte J3': 12, 'Carte J4': 6, 'Etape': 21},
#  {'Carte J1': 3, 'Carte J2': 3, 'Carte J3': 7, 'Carte J4': 13, 'Etape': 22},
#  {'Carte J1': 13, 'Carte J2': 3, 'Carte J3': 2, 'Carte J4': 8, 'Etape': 23},
#  {'Carte J1': 8, 'Carte J2': 6, 'Carte J3': 13, 'Carte J4': 7, 'Etape': 24},
#  {'Carte J1': 11, 'Carte J2': 3, 'Carte J3': 12, 'Carte J4': 1, 'Etape': 25},
#  {'Carte J1': 4, 'Carte J2': 1, 'Carte J3': 5, 'Carte J4': 6, 'Etape': 26},
#  {'Carte J1': 8, 'Carte J2': 11, 'Carte J3': 8, 'Carte J4': 2, 'Etape': 27},
#  {'Carte J1': 7, 'Carte J2': 2, 'Carte J3': 8, 'Carte J4': 13, 'Etape': 28},
#  {'Carte J1': 8, 'Carte J2': 9, 'Carte J3': 12, 'Carte J4': 1, 'Etape': 29},
#  {'Carte J1': 9, 'Carte J2': 10, 'Carte J3': 4, 'Carte J4': 2, 'Etape': 30},
#  {'Carte J1': 13, 'Carte J2': 9, 'Carte J3': 5, 'Carte J4': 11, 'Etape': 31}]
# Le gagant est Joueur 3 en 31 étapes

# %% [markdown]
# On définit les variables pour matplotlib,
# la liste d'abscisse (chaque étape de la partie)
# les listes des cartes de chaque joueur

# %%
# Listes pour matplotlib
liste_x = [i for i in range(len(partie))] # Chaque étape de la partie
liste_y_j1 = [partie[i]["Carte J1"] for i in liste_x] # Carte du joueur 1
liste_y_j2 = [partie[i]["Carte J2"] for i in liste_x] # Carte du joueur 2
liste_y_j3 = [partie[i]["Carte J3"] for i in liste_x] # Carte du joueur 3
liste_y_j4 = [partie[i]["Carte J4"] for i in liste_x] # Carte du joueur 4

# Largeur des barres
largeur = 0.5

# %% [markdown]
# On crée le graphique pour chaque joueur

# %%
fig = plt.figure()

plt.bar(liste_x, liste_y_j1, width=largeur, label="Joueur 1", color=(0.1, 0.6, 0.8, 1.0))

# Ajout des légendes
plt.title("Cartes jouées à chaque étape")
plt.xlabel("Etapes")
plt.ylabel("Cartes jouées")
plt.legend()

#plt.grid()
plt.show()

# %%
fig = plt.figure()

plt.bar(liste_x, liste_y_j2, width=largeur, label="Joueur 2", color=(0.8, 0.1, 0.6, 1.0))

# Ajout des légendes
plt.title("Cartes jouées à chaque étape")
plt.xlabel("Etapes")
plt.ylabel("Cartes jouées")
plt.legend()

#plt.grid()
plt.show()

# %%
fig = plt.figure()

plt.bar(liste_x, liste_y_j3, width=largeur, label="Joueur 3", color=(0.1, 0.6, 0.1, 1.0))

# Ajout des légendes
plt.title("Cartes jouées à chaque étape")
plt.xlabel("Etapes")
plt.ylabel("Cartes jouées")
plt.legend()

#plt.grid()
plt.show()

# %%
fig = plt.figure()

plt.bar(liste_x, liste_y_j4, width=largeur, label="Joueur 4", color=(0.6, 0.1, 0.6, 1.0))

# Ajout des légendes
plt.title("Cartes jouées à chaque étape")
plt.xlabel("Etapes")
plt.ylabel("Cartes jouées")
plt.legend()

#plt.grid()
plt.show()

# %% [markdown]
# On crée une fonction pour créé le tableau CSV pour les simulations

# %%
# Fonction pour crée le tableau avec les informations des simulations de chaque partie
def export_csv(tableau, nom_fichier, ordre):
    with open(nom_fichier, "w", newline="") as fichier:
        writer = csv.DictWriter(fichier, fieldnames=ordre)
        writer.writeheader()

        for ligne in tableau:
            writer.writerow(ligne)
    
    return None

# %% [markdown]
# Enfin on crée une fonction pour simuler N parties

# %%
# Fonction pour simuler n parties
def simuler_parties(n: int):
    nb_etapes = []
    nb_partie = 1
    tableau = []

    ordre = ["Partie", "Joueur Gagnant", "Nombres de coups", "Durée"]

    for _ in range(n):
        partie, gagnant = lancer_partie(joueur_1, joueur_2, joueur_3, joueur_4)
        nb_etapes.append(len(partie))

        tableau.append({
            "Partie": nb_partie,
            "Joueur Gagnant": gagnant,
            "Nombres de coups": len(partie),
            "Durée": len(partie) / regles["nb_joueurs"]
        })

        nb_partie += 1


    print(nb_etapes)
    #print(tableau)

    # Export du tableau
    export_csv(tableau, "parties.csv", ordre)

    # Affichage du minimum, du maximum et de la moyenne
    nb_etapes_minimum = min(nb_etapes)
    nb_etapes_maximum = max(nb_etapes)
    nb_etapes_moyenne = sum(nb_etapes) / len(nb_etapes)

    print(f"Le nombre minimum d'étapes est {nb_etapes_minimum}.")
    print(f"Le nombre maximum d'étapes est {nb_etapes_maximum}.")
    print(f"La moyenne d'étapes est {nb_etapes_moyenne}.")

# %%
nb_parties = 100
simuler_parties(nb_parties)
# Out:
# [22, 15, 18, 28, 13, 11, 24, 18, 51, 15, 19, 20, 18, 37, 33, 23, 54, 43, 45, 13, 6, 70, 70, 7, 35, 62, 26, 13, 13, 19, 25, 21, 20, 11, 9, 25, 23, 17, 19, 20, 56, 17, 15, 16, 16, 31, 44, 42, 17, 47, 23, 48, 21, 10, 13, 20, 29, 25, 47, 27, 44, 19, 30, 10, 11, 10, 7, 10, 9, 18, 25, 30, 9, 20, 16, 25, 9, 17, 17, 38, 17, 41, 13, 6, 39, 7, 33, 12, 13, 21, 10, 12, 22, 8, 14, 22, 20, 10, 19, 25]
# Le nombre minimum d'étapes est 6.
# Le nombre maximum d'étapes est 70.
# La moyenne d'étapes est 23.33.
